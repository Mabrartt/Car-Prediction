# %% [markdown]
# IMPORT LIBRARIES

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# IMPORT DATASET

# %%
df = pd.read_csv(r'D:\Latihan Car Predict\car_price_prediction.csv')
df.head(10)
# Out:
#          ID  Price  Levy Manufacturer     Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS    RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET   Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA       FIT        2006  Hatchback
# 3  45769185   3607   862         FORD    Escape        2011       Jeep
# 4  45809263  11726   446        HONDA       FIT        2014  Hatchback
# 5  45802912  39493   891      HYUNDAI  Santa FE        2016       Jeep
# 6  45656768   1803   761       TOYOTA     Prius        2010  Hatchback
# 7  45816158    549   751      HYUNDAI    Sonata        2013      Sedan
# 8  45641395   1098   394       TOYOTA     Camry        2014      Sedan
# 9  45756839  26657     -        LEXUS    RX 350        2007       Jeep
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
# 5              Yes    Diesel             2  160931 km        4.0
# 6              Yes    Hybrid           1.8  258909 km        4.0
# 7              Yes    Petrol           2.4  216118 km        4.0
# 8              Yes    Hybrid           2.5  398069 km        4.0
# 9              Yes    Petrol           3.5  128500 km        6.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# 1     Tiptronic          4x4  04-May        Left wheel   Black        8
# 2      Variator        Front  04-May  Right-hand drive   Black        2
# 3     Automatic          4x4  04-May        Left wheel   White        0
# 4     Automatic        Front  04-May        Left wheel  Silver        4
# 5     Automatic        Front  04-May        Left wheel   White        4
# 6     Automatic        Front  04-May        Left wheel   White       12
# 7     Automatic        Front  04-May        Left wheel    Grey       12
# 8     Automatic        Front  04-May        Left wheel   Black       12
# 9     Automatic          4x4  04-May        Left wheel  Silver       12

# %% [markdown]
# PREPROCESS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19237 non-null  int64
#  1   Price             19237 non-null  int64
#  2   Levy              19237 non-null  object
#  3   Manufacturer      19237 non-null  object
#  4   Model             19237 non-null  object
#  5   Prod. year        19237 non-null  int64
#  6   Category          19237 non-null  object
#  7   Leather interior  19237 non-null  object
#  8   Fuel type         19237 non-null  object
#  9   Engine volume     19237 non-null  object
#  10  Mileage           19237 non-null  object
#  11  Cylinders         19237 non-null  float64
#  12  Gear box type     19237 non-null  object
#  13  Drive wheels      19237 non-null  object
#  14  Doors             19237 non-null  object
#  15  Wheel             19237 non-null  object
#  16  Color             19237 non-null  object
#  17  Airbags           19237 non-null  int64
# dtypes: float64(1), int64(4), object(13)
# memory usage: 2.6+ MB

# %%
df.shape
# Out:
# (19237, 18)

# %%
df.isna().sum()
# Out:
# ID                  0
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# dtype: int64

# %%
df.drop(['Levy', 'Doors', 'Wheel'], axis = 1, inplace = True)
df.head(10)
# Out:
#          ID  Price Manufacturer     Model  Prod. year   Category  \
# 0  45654403  13328        LEXUS    RX 450        2010       Jeep
# 1  44731507  16621    CHEVROLET   Equinox        2011       Jeep
# 2  45774419   8467        HONDA       FIT        2006  Hatchback
# 3  45769185   3607         FORD    Escape        2011       Jeep
# 4  45809263  11726        HONDA       FIT        2014  Hatchback
# 5  45802912  39493      HYUNDAI  Santa FE        2016       Jeep
# 6  45656768   1803       TOYOTA     Prius        2010  Hatchback
# 7  45816158    549      HYUNDAI    Sonata        2013      Sedan
# 8  45641395   1098       TOYOTA     Camry        2014      Sedan
# 9  45756839  26657        LEXUS    RX 350        2007       Jeep
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
# 5              Yes    Diesel             2  160931 km        4.0
# 6              Yes    Hybrid           1.8  258909 km        4.0
# 7              Yes    Petrol           2.4  216118 km        4.0
# 8              Yes    Hybrid           2.5  398069 km        4.0
# 9              Yes    Petrol           3.5  128500 km        6.0
#
#   Gear box type Drive wheels   Color  Airbags
# 0     Automatic          4x4  Silver       12
# 1     Tiptronic          4x4   Black        8
# 2      Variator        Front   Black        2
# 3     Automatic          4x4   White        0
# 4     Automatic        Front  Silver        4
# 5     Automatic        Front   White        4
# 6     Automatic        Front   White       12
# 7     Automatic        Front    Grey       12
# 8     Automatic        Front   Black       12
# 9     Automatic          4x4  Silver       12

# %%
print(df["Manufacturer"].unique())
print(df["Model"].unique())
print(df["Fuel type"].unique())
print(df["Category"].unique())
print(df["Gear box type"].unique())
print(df["Drive wheels"].unique())
# Out:
# ['LEXUS' 'CHEVROLET' 'HONDA' 'FORD' 'HYUNDAI' 'TOYOTA' 'MERCEDES-BENZ'
#  'OPEL' 'PORSCHE' 'BMW' 'JEEP' 'VOLKSWAGEN' 'AUDI' 'RENAULT' 'NISSAN'
#  'SUBARU' 'DAEWOO' 'KIA' 'MITSUBISHI' 'SSANGYONG' 'MAZDA' 'GMC' 'FIAT'
#  'INFINITI' 'ALFA ROMEO' 'SUZUKI' 'ACURA' 'LINCOLN' 'VAZ' 'GAZ' 'CITROEN'
#  'LAND ROVER' 'MINI' 'DODGE' 'CHRYSLER' 'JAGUAR' 'ISUZU' 'SKODA'
#  'DAIHATSU' 'BUICK' 'TESLA' 'CADILLAC' 'PEUGEOT' 'BENTLEY' 'VOLVO' 'სხვა'
#  'HAVAL' 'HUMMER' 'SCION' 'UAZ' 'MERCURY' 'ZAZ' 'ROVER' 'SEAT' 'LANCIA'
#  'MOSKVICH' 'MASERATI' 'FERRARI' 'SAAB' 'LAMBORGHINI' 'ROLLS-ROYCE'
#  'PONTIAC' 'SATURN' 'ASTON MARTIN' 'GREATWALL']
# ['RX 450' 'Equinox' 'FIT' ... 'E 230 124' 'RX 450 F SPORT' 'Prius C aqua']
# ['Hybrid' 'Petrol' 'Diesel' 'CNG' 'Plug-in Hybrid' 'LPG' 'Hydrogen']
# ['Jeep' 'Hatchback' 'Sedan' 'Microbus' 'Goods wagon' 'Universal' 'Coupe'
#  'Minivan' 'Cabriolet' 'Limousine' 'Pickup']
# ['Automatic' 'Tiptronic' 'Variator' 'Manual']
# ['4x4' 'Front' 'Rear']

# %%
final_df = df[['Price', 'Manufacturer', 'Model', 'Prod. year', 'Category', 'Leather interior', 'Fuel type', 'Mileage', 'Gear box type', 'Drive wheels', 'Color']]
final_df.head(10)
# Out:
#    Price Manufacturer     Model  Prod. year   Category Leather interior  \
# 0  13328        LEXUS    RX 450        2010       Jeep              Yes
# 1  16621    CHEVROLET   Equinox        2011       Jeep               No
# 2   8467        HONDA       FIT        2006  Hatchback               No
# 3   3607         FORD    Escape        2011       Jeep              Yes
# 4  11726        HONDA       FIT        2014  Hatchback              Yes
# 5  39493      HYUNDAI  Santa FE        2016       Jeep              Yes
# 6   1803       TOYOTA     Prius        2010  Hatchback              Yes
# 7    549      HYUNDAI    Sonata        2013      Sedan              Yes
# 8   1098       TOYOTA     Camry        2014      Sedan              Yes
# 9  26657        LEXUS    RX 350        2007       Jeep              Yes
#
#   Fuel type    Mileage Gear box type Drive wheels   Color
# 0    Hybrid  186005 km     Automatic          4x4  Silver
# 1    Petrol  192000 km     Tiptronic          4x4   Black
# 2    Petrol  200000 km      Variator        Front   Black
# 3    Hybrid  168966 km     Automatic          4x4   White
# 4    Petrol   91901 km     Automatic        Front  Silver
# 5    Diesel  160931 km     Automatic        Front   White
# 6    Hybrid  258909 km     Automatic        Front   White
# 7    Petrol  216118 km     Automatic        Front    Grey
# 8    Hybrid  398069 km     Automatic        Front   Black
# 9    Petrol  128500 km     Automatic          4x4  Silver

# %%
final_df['Current year'] = 2023
final_df.head(10)
# Out:
#    Price Manufacturer     Model  Prod. year   Category Leather interior  \
# 0  13328        LEXUS    RX 450        2010       Jeep              Yes
# 1  16621    CHEVROLET   Equinox        2011       Jeep               No
# 2   8467        HONDA       FIT        2006  Hatchback               No
# 3   3607         FORD    Escape        2011       Jeep              Yes
# 4  11726        HONDA       FIT        2014  Hatchback              Yes
# 5  39493      HYUNDAI  Santa FE        2016       Jeep              Yes
# 6   1803       TOYOTA     Prius        2010  Hatchback              Yes
# 7    549      HYUNDAI    Sonata        2013      Sedan              Yes
# 8   1098       TOYOTA     Camry        2014      Sedan              Yes
# 9  26657        LEXUS    RX 350        2007       Jeep              Yes
#
#   Fuel type    Mileage Gear box type Drive wheels   Color  Current year
# 0    Hybrid  186005 km     Automatic          4x4  Silver          2023
# 1    Petrol  192000 km     Tiptronic          4x4   Black          2023
# 2    Petrol  200000 km      Variator        Front   Black          2023
# 3    Hybrid  168966 km     Automatic          4x4   White          2023
# 4    Petrol   91901 km     Automatic        Front  Silver          2023
# 5    Diesel  160931 km     Automatic        Front   White          2023
# 6    Hybrid  258909 km     Automatic        Front   White          2023
# 7    Petrol  216118 km     Automatic        Front    Grey          2023
# 8    Hybrid  398069 km     Automatic        Front   Black          2023
# 9    Petrol  128500 km     Automatic          4x4  Silver          2023

# %%
final_df['Mileage'] = final_df['Mileage'].str.replace(" km", "")

# %%
final_df['Car age'] = final_df['Current year'] - final_df['Prod. year']
final_df.head(10)
# Out:
#    Price Manufacturer     Model  Prod. year   Category Leather interior  \
# 0  13328        LEXUS    RX 450        2010       Jeep              Yes
# 1  16621    CHEVROLET   Equinox        2011       Jeep               No
# 2   8467        HONDA       FIT        2006  Hatchback               No
# 3   3607         FORD    Escape        2011       Jeep              Yes
# 4  11726        HONDA       FIT        2014  Hatchback              Yes
# 5  39493      HYUNDAI  Santa FE        2016       Jeep              Yes
# 6   1803       TOYOTA     Prius        2010  Hatchback              Yes
# 7    549      HYUNDAI    Sonata        2013      Sedan              Yes
# 8   1098       TOYOTA     Camry        2014      Sedan              Yes
# 9  26657        LEXUS    RX 350        2007       Jeep              Yes
#
#   Fuel type Mileage Gear box type Drive wheels   Color  Current year  Car age
# 0    Hybrid  186005     Automatic          4x4  Silver          2023       13
# 1    Petrol  192000     Tiptronic          4x4   Black          2023       12
# 2    Petrol  200000      Variator        Front   Black          2023       17
# 3    Hybrid  168966     Automatic          4x4   White          2023       12
# 4    Petrol   91901     Automatic        Front  Silver          2023        9
# 5    Diesel  160931     Automatic        Front   White          2023        7
# 6    Hybrid  258909     Automatic        Front   White          2023       13
# 7    Petrol  216118     Automatic        Front    Grey          2023       10
# 8    Hybrid  398069     Automatic        Front   Black          2023        9
# 9    Petrol  128500     Automatic          4x4  Silver          2023       16

# %%
final_df.drop(['Current year'], axis = 1, inplace = True)

# %%
final_df['Mileage'] = [float(value.split(' ')[0]) for value in df['Mileage']]

# %%
final_df.head(10)
# Out:
#    Price Manufacturer     Model  Prod. year   Category Leather interior  \
# 0  13328        LEXUS    RX 450        2010       Jeep              Yes
# 1  16621    CHEVROLET   Equinox        2011       Jeep               No
# 2   8467        HONDA       FIT        2006  Hatchback               No
# 3   3607         FORD    Escape        2011       Jeep              Yes
# 4  11726        HONDA       FIT        2014  Hatchback              Yes
# 5  39493      HYUNDAI  Santa FE        2016       Jeep              Yes
# 6   1803       TOYOTA     Prius        2010  Hatchback              Yes
# 7    549      HYUNDAI    Sonata        2013      Sedan              Yes
# 8   1098       TOYOTA     Camry        2014      Sedan              Yes
# 9  26657        LEXUS    RX 350        2007       Jeep              Yes
#
#   Fuel type   Mileage Gear box type Drive wheels   Color  Car age
# 0    Hybrid  186005.0     Automatic          4x4  Silver       13
# 1    Petrol  192000.0     Tiptronic          4x4   Black       12
# 2    Petrol  200000.0      Variator        Front   Black       17
# 3    Hybrid  168966.0     Automatic          4x4   White       12
# 4    Petrol   91901.0     Automatic        Front  Silver        9
# 5    Diesel  160931.0     Automatic        Front   White        7
# 6    Hybrid  258909.0     Automatic        Front   White       13
# 7    Petrol  216118.0     Automatic        Front    Grey       10
# 8    Hybrid  398069.0     Automatic        Front   Black        9
# 9    Petrol  128500.0     Automatic          4x4  Silver       16

# %%
final_df['Manufacturer'].value_counts()
# Out:
# HYUNDAI          3769
# TOYOTA           3662
# MERCEDES-BENZ    2076
# FORD             1111
# CHEVROLET        1069
#                  ...
# TESLA               1
# PONTIAC             1
# SATURN              1
# ASTON MARTIN        1
# GREATWALL           1
# Name: Manufacturer, Length: 65, dtype: int64

# %%
final_df.describe()
# Out:
#               Price    Prod. year       Mileage       Car age
# count  1.923700e+04  19237.000000  1.923700e+04  19237.000000
# mean   1.855593e+04   2010.912824  1.532236e+06     12.087176
# std    1.905813e+05      5.668673  4.840387e+07      5.668673
# min    1.000000e+00   1939.000000  0.000000e+00      3.000000
# 25%    5.331000e+03   2009.000000  7.013900e+04      8.000000
# 50%    1.317200e+04   2012.000000  1.260000e+05     11.000000
# 75%    2.207500e+04   2015.000000  1.888880e+05     14.000000
# max    2.630750e+07   2020.000000  2.147484e+09     84.000000

# %%
final_df = final_df[final_df['Price']<7e6].reset_index(drop=True)

# %%
final_df
# Out:
#        Price   Manufacturer    Model  Prod. year   Category Leather interior  \
# 0      13328          LEXUS   RX 450        2010       Jeep              Yes
# 1      16621      CHEVROLET  Equinox        2011       Jeep               No
# 2       8467          HONDA      FIT        2006  Hatchback               No
# 3       3607           FORD   Escape        2011       Jeep              Yes
# 4      11726          HONDA      FIT        2014  Hatchback              Yes
# ...      ...            ...      ...         ...        ...              ...
# 19231   8467  MERCEDES-BENZ  CLK 200        1999      Coupe              Yes
# 19232  15681        HYUNDAI   Sonata        2011      Sedan              Yes
# 19233  26108        HYUNDAI   Tucson        2010       Jeep              Yes
# 19234   5331      CHEVROLET  Captiva        2007       Jeep              Yes
# 19235    470        HYUNDAI   Sonata        2012      Sedan              Yes
#
#       Fuel type   Mileage Gear box type Drive wheels   Color  Car age
# 0        Hybrid  186005.0     Automatic          4x4  Silver       13
# 1        Petrol  192000.0     Tiptronic          4x4   Black       12
# 2        Petrol  200000.0      Variator        Front   Black       17
# 3        Hybrid  168966.0     Automatic          4x4   White       12
# 4        Petrol   91901.0     Automatic        Front  Silver        9
# ...         ...       ...           ...          ...     ...      ...
# 19231       CNG  300000.0        Manual         Rear  Silver       24
# 19232    Petrol  161600.0     Tiptronic        Front     Red       12
# 19233    Diesel  116365.0     Automatic        Front    Grey       13
# 19234    Diesel   51258.0     Automatic        Front   Black       16
# 19235    Hybrid  186923.0     Automatic        Front   White       11
#
# [19236 rows x 12 columns]

# %%
# final_df.to_csv('Cleaned df.csv')

# %% [markdown]
# MODELS

# %%
X = final_df.drop(columns = 'Price')
y = final_df['Price']

# %%
X
# Out:
#         Manufacturer    Model  Prod. year   Category Leather interior  \
# 0              LEXUS   RX 450        2010       Jeep              Yes
# 1          CHEVROLET  Equinox        2011       Jeep               No
# 2              HONDA      FIT        2006  Hatchback               No
# 3               FORD   Escape        2011       Jeep              Yes
# 4              HONDA      FIT        2014  Hatchback              Yes
# ...              ...      ...         ...        ...              ...
# 19231  MERCEDES-BENZ  CLK 200        1999      Coupe              Yes
# 19232        HYUNDAI   Sonata        2011      Sedan              Yes
# 19233        HYUNDAI   Tucson        2010       Jeep              Yes
# 19234      CHEVROLET  Captiva        2007       Jeep              Yes
# 19235        HYUNDAI   Sonata        2012      Sedan              Yes
#
#       Fuel type   Mileage Gear box type Drive wheels   Color  Car age
# 0        Hybrid  186005.0     Automatic          4x4  Silver       13
# 1        Petrol  192000.0     Tiptronic          4x4   Black       12
# 2        Petrol  200000.0      Variator        Front   Black       17
# 3        Hybrid  168966.0     Automatic          4x4   White       12
# 4        Petrol   91901.0     Automatic        Front  Silver        9
# ...         ...       ...           ...          ...     ...      ...
# 19231       CNG  300000.0        Manual         Rear  Silver       24
# 19232    Petrol  161600.0     Tiptronic        Front     Red       12
# 19233    Diesel  116365.0     Automatic        Front    Grey       13
# 19234    Diesel   51258.0     Automatic        Front   Black       16
# 19235    Hybrid  186923.0     Automatic        Front   White       11
#
# [19236 rows x 11 columns]

# %%
y
# Out:
# 0        13328
# 1        16621
# 2         8467
# 3         3607
# 4        11726
#          ...
# 19231     8467
# 19232    15681
# 19233    26108
# 19234     5331
# 19235      470
# Name: Price, Length: 19236, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
ohe=OneHotEncoder()
ohe.fit(X[['Manufacturer', 'Category', 'Fuel type', 'Gear box type']])
# Out:
# OneHotEncoder()

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['Manufacturer', 'Category', 'Fuel type', 'Gear box type']),
                                    remainder='passthrough')

# %%
lr = LinearRegression()

# %%
pipe=make_pipeline(column_trans,lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\compose\_column_transformer.py:846, in ColumnTransformer._hstack(self, Xs)
#     842 try:
#     843     # since all columns should be numeric before stacking them
#     844     # in a sparse matrix, `check_array` is used for the
#     845     # dtype conversion if necessary.
# --> 846     converted_Xs = [
#     847         check_array(X, accept_sparse=True, force_all_finite=False)
#     848         for X in Xs
#     849     ]
#     850 except ValueError as e:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\compose\_column_transformer.py:847, in <listcomp>(.0)
#     842 try:
#     843     # since all columns should be numeric before stacking them
#     844     # in a sparse matrix, `check_array` is used for the
#     845     # dtype conversion if necessary.
#     846     converted_Xs = [
# --> 847         check_array(X, accept_sparse=True, force_all_finite=False)
#     848         for X in Xs
#     849     ]
#     850 except ValueError as e:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\validation.py:917, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     916     else:
# --> 917         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     918 except ComplexWarning as complex_warning:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\_array_api.py:380, in _asarray_with_order(array, dtype, order, copy, xp)
#     379 else:
# --> 380     array = numpy.asarray(array, order=order, dtype=dtype)
#     382 # At this point array is a NumPy ndarray. We convert it to an array
#     383 # container that is consistent with the input's namespace.
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:2070, in NDFrame.__array__(self, dtype)
#    2069 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2070     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'Prius'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 pipe.fit(X_train,y_train)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\pipeline.py:416, in Pipeline.fit(self, X, y, **fit_params)
#     390 """Fit the model.
#     391
#     392 Fit all the transformers one after the other and transform the
#    (...)
#     413     Pipeline with fitted steps.
#     414 """
#     415 fit_params_steps = self._check_fit_params(**fit_params)
# --> 416 Xt = self._fit(X, y, **fit_params_steps)
#     417 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     418     if self._final_estimator != "passthrough":
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\pipeline.py:370, in Pipeline._fit(self, X, y, **fit_params_steps)
#     368     cloned_transformer = clone(transformer)
#     369 # Fit or load from cache the current transformer
# --> 370 X, fitted_transformer = fit_transform_one_cached(
#     371     cloned_transformer,
#     372     X,
#     373     y,
#     374     None,
#     375     message_clsname="Pipeline",
#     376     message=self._log_message(step_idx),
#     377     **fit_params_steps[name],
#     378 )
#     379 # Replace the transformer of the step with the fitted
#     380 # transformer. This is necessary when loading the transformer
#     381 # from the cache.
#     382 self.steps[step_idx] = (name, fitted_transformer)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\joblib\memory.py:353, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     352 def __call__(self, *args, **kwargs):
# --> 353     return self.func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\pipeline.py:950, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     948 with _print_elapsed_time(message_clsname, message):
#     949     if hasattr(transformer, "fit_transform"):
# --> 950         res = transformer.fit_transform(X, y, **fit_params)
#     951     else:
#     952         res = transformer.fit(X, y, **fit_params).transform(X)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\compose\_column_transformer.py:767, in ColumnTransformer.fit_transform(self, X, y)
#     764 self._validate_output(Xs)
#     765 self._record_output_indices(Xs)
# --> 767 return self._hstack(list(Xs))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\compose\_column_transformer.py:851, in ColumnTransformer._hstack(self, Xs)
#     846         converted_Xs = [
#     847             check_array(X, accept_sparse=True, force_all_finite=False)
#     848             for X in Xs
#     849         ]
#     850     except ValueError as e:
# --> 851         raise ValueError(
#     852             "For a sparse output, all columns should "
#     853             "be a numeric or convertible to a numeric."
#     854         ) from e
#     856     return sparse.hstack(converted_Xs).tocsr()
#     857 else:
#
# ValueError: For a sparse output, all columns should be a numeric or convertible to a numeric.
